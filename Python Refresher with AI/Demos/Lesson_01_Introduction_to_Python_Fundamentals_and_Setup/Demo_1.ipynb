# %%
# single line comment
print("hello");
# Out:
# hello

# %%
'''
This is a multi-line comment
spanning multiple lines.
'''
name = input("Enter your name: ")
print(f"Hello, {name}!  Welcome to the Python world.");
# Out:
# Hello, 3!  Welcome to the Python world.
